# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from citipy import citipy

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#Create a list for holding the names of cities.
cities = list()

#Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    cities_name = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list.
    if cities_name not in cities:
        cities.append(cities_name)

len(cities)
# Out:
# 767

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8bfdfd30733a60a6c2d3329932b4eb83

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

print(len(city_data))
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | kapaa
# Processing Record 4 of Set 1 | dwarka
# Processing Record 5 of Set 1 | minas
# Processing Record 6 of Set 1 | tiksi
# Processing Record 7 of Set 1 | cherskiy
# Processing Record 8 of Set 1 | tondano
# Processing Record 9 of Set 1 | ponta do sol
# Processing Record 10 of Set 1 | dingle
# Processing Record 11 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 1 | yellowknife
# Processing Record 13 of Set 1 | saldanha
# Processing Record 14 of Set 1 | vaini
# Processing Record 15 of Set 1 | qaanaaq
# Processing Record 16 of Set 1 | lancaster
# Processing Record 17 of Set 1 | grand gaube
# Processing Record 18 of Set 1 | khatanga
# Processing Record 19 of Set 1 | clyde river
# Processing Record 20 of Set 1 | port elizabeth
# Processing Record 21 of Set 1 | antsohihy
# Processing Record 22 of Set 1 | puchezh
# Processing Record 23 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 1 | bethel
# Processing Record 25 of Set 1 | avera
# Processing Record 26 of Set 1 | arrecife
# Processing Record 27 of Set 1 | mount isa
# Processing Record 28 of Set 1 | karratha
# Processing Record 29 of Set 1 | coahuayana
# Processing Record 30 of Set 1 | novokruchininskiy
# Processing Record 31 of Set 1 | ixtapa
# Processing Record 32 of Set 1 | haapu
# City not found. Skipping...
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | hilo
# Processing Record 35 of Set 1 | georgetown
# Processing Record 36 of Set 1 | aransas pass
# Processing Record 37 of Set 1 | cidreira
# Processing Record 38 of Set 1 | laguna
# Processing Record 39 of Set 1 | mahebourg
# Processing Record 40 of Set 1 | tuktoyaktuk
# Processing Record 41 of Set 1 | ushuaia
# Processing Record 42 of Set 1 | kota tinggi
# Processing Record 43 of Set 1 | barao de melgaco
# Processing Record 44 of Set 1 | hovd
# Processing Record 45 of Set 1 | kulhudhuffushi
# Processing Record 46 of Set 1 | mataura
# Processing Record 47 of Set 1 | sydney
# Processing Record 48 of Set 1 | teknaf
# Processing Record 49 of Set 1 | bluff
# Processing Record 50 of Set 1 | aklavik
# Processing Record 1 of Set 2 | sakakah
# Processing Record 2 of Set 2 | puerto ayora
# Processing Record 3 of Set 2 | constitucion
# Processing Record 4 of Set 2 | port lincoln
# Processing Record 5 of Set 2 | poopo
# Processing Record 6 of Set 2 | ostrovnoy
# Processing Record 7 of Set 2 | huzhou
# Processing Record 8 of Set 2 | new norfolk
# Processing Record 9 of Set 2 | port alfred
# Processing Record 10 of Set 2 | upernavik
# Processing Record 11 of Set 2 | ulaangom
# Processing Record 12 of Set 2 | chuy
# Processing Record 13 of Set 2 | srednekolymsk
# Processing Record 14 of Set 2 | jamestown
# Processing Record 15 of Set 2 | torbay
# Processing Record 16 of Set 2 | nikko
# Processing Record 17 of Set 2 | staryy nadym
# Processing Record 18 of Set 2 | rikitea
# Processing Record 19 of Set 2 | tezu
# Processing Record 20 of Set 2 | bathsheba
# Processing Record 21 of Set 2 | bredasdorp
# Processing Record 22 of Set 2 | barrow
# Processing Record 23 of Set 2 | faanui
# Processing Record 24 of Set 2 | joao pinheiro
# Processing Record 25 of Set 2 | hithadhoo
# Processing Record 26 of Set 2 | isugod
# Processing Record 27 of Set 2 | chernyshevskiy
# Processing Record 28 of Set 2 | namibe
# Processing Record 29 of Set 2 | dikson
# Processing Record 30 of Set 2 | hunza
# City not found. Skipping...
# Processing Record 31 of Set 2 | port macquarie
# Processing Record 32 of Set 2 | paraiso
# Processing Record 33 of Set 2 | longyearbyen
# Processing Record 34 of Set 2 | saint-philippe
# Processing Record 35 of Set 2 | isangel
# Processing Record 36 of Set 2 | nabire
# Processing Record 37 of Set 2 | moen
# Processing Record 38 of Set 2 | lagoa
# Processing Record 39 of Set 2 | churapcha
# Processing Record 40 of Set 2 | murgab
# Processing Record 41 of Set 2 | oak harbor
# Processing Record 42 of Set 2 | orangeburg
# Processing Record 43 of Set 2 | saskylakh
# Processing Record 44 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 2 | thompson
# Processing Record 46 of Set 2 | belaya gora
# Processing Record 47 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 2 | nizhniy ufaley
# Processing Record 49 of Set 2 | hailar
# Processing Record 50 of Set 2 | cabo san lucas
# Processing Record 1 of Set 3 | nauta
# Processing Record 2 of Set 3 | atuona
# Processing Record 3 of Set 3 | busselton
# Processing Record 4 of Set 3 | hasaki
# Processing Record 5 of Set 3 | stromness
# Processing Record 6 of Set 3 | upington
# Processing Record 7 of Set 3 | cape town
# Processing Record 8 of Set 3 | airai
# Processing Record 9 of Set 3 | shihezi
# Processing Record 10 of Set 3 | buxar
# Processing Record 11 of Set 3 | ahuimanu
# Processing Record 12 of Set 3 | boa vista
# Processing Record 13 of Set 3 | the valley
# Processing Record 14 of Set 3 | dhidhdhoo
# Processing Record 15 of Set 3 | mitha tiwana
# Processing Record 16 of Set 3 | klaksvik
# Processing Record 17 of Set 3 | clarence town
# Processing Record 18 of Set 3 | mirnyy
# Processing Record 19 of Set 3 | manokwari
# Processing Record 20 of Set 3 | lasa
# Processing Record 21 of Set 3 | bandar-e lengeh
# Processing Record 22 of Set 3 | atasu
# Processing Record 23 of Set 3 | sokoto
# Processing Record 24 of Set 3 | kieta
# Processing Record 25 of Set 3 | albany
# Processing Record 26 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 3 | ortigueira
# Processing Record 28 of Set 3 | talcahuano
# Processing Record 29 of Set 3 | wonthaggi
# Processing Record 30 of Set 3 | vagay
# Processing Record 31 of Set 3 | katsuura
# Processing Record 32 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 3 | banmo
# City not found. Skipping...
# Processing Record 34 of Set 3 | astana
# Processing Record 35 of Set 3 | bozdar
# Processing Record 36 of Set 3 | gat
# Processing Record 37 of Set 3 | carnarvon
# Processing Record 38 of Set 3 | chokurdakh
# Processing Record 39 of Set 3 | ribeira grande
# Processing Record 40 of Set 3 | murakami
# Processing Record 41 of Set 3 | aswan
# Processing Record 42 of Set 3 | mar del plata
# Processing Record 43 of Set 3 | sami
# Processing Record 44 of Set 3 | sabang
# Processing Record 45 of Set 3 | la libertad
# Processing Record 46 of Set 3 | buala
# Processing Record 47 of Set 3 | arraial do cabo
# Processing Record 48 of Set 3 | lebu
# Processing Record 49 of Set 3 | uppsala
# Processing Record 50 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 1 of Set 4 | yerbogachen
# Processing Record 2 of Set 4 | carutapera
# Processing Record 3 of Set 4 | nyimba
# Processing Record 4 of Set 4 | aztec
# Processing Record 5 of Set 4 | nikolskoye
# Processing Record 6 of Set 4 | pekalongan
# Processing Record 7 of Set 4 | samarai
# Processing Record 8 of Set 4 | yakeshi
# Processing Record 9 of Set 4 | constantine
# Processing Record 10 of Set 4 | norman wells
# Processing Record 11 of Set 4 | rocha
# Processing Record 12 of Set 4 | provideniya
# Processing Record 13 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 4 | barabinsk
# Processing Record 15 of Set 4 | severo-kurilsk
# Processing Record 16 of Set 4 | khorixas
# Processing Record 17 of Set 4 | bilma
# Processing Record 18 of Set 4 | san cristobal
# Processing Record 19 of Set 4 | lushunkou
# City not found. Skipping...
# Processing Record 20 of Set 4 | abonnema
# Processing Record 21 of Set 4 | lakes entrance
# Processing Record 22 of Set 4 | moree
# Processing Record 23 of Set 4 | east london
# Processing Record 24 of Set 4 | winslow
# Processing Record 25 of Set 4 | guymon
# Processing Record 26 of Set 4 | opunake
# Processing Record 27 of Set 4 | soc trang
# Processing Record 28 of Set 4 | moiyabana
# City not found. Skipping...
# Processing Record 29 of Set 4 | nouakchott
# Processing Record 30 of Set 4 | kodiak
# Processing Record 31 of Set 4 | poum
# Processing Record 32 of Set 4 | one hundred mile house
# City not found. Skipping...
# Processing Record 33 of Set 4 | mendahara
# City not found. Skipping...
# Processing Record 34 of Set 4 | iqaluit
# Processing Record 35 of Set 4 | mareeba
# Processing Record 36 of Set 4 | butaritari
# Processing Record 37 of Set 4 | ambanja
# Processing Record 38 of Set 4 | mabaruma
# Processing Record 39 of Set 4 | saint george
# Processing Record 40 of Set 4 | bokspits
# City not found. Skipping...
# Processing Record 41 of Set 4 | mutsu
# Processing Record 42 of Set 4 | illapel
# Processing Record 43 of Set 4 | greenville
# Processing Record 44 of Set 4 | fuyang
# Processing Record 45 of Set 4 | santa cruz
# Processing Record 46 of Set 4 | miastko
# Processing Record 47 of Set 4 | meulaboh
# Processing Record 48 of Set 4 | janauba
# Processing Record 49 of Set 4 | kabanjahe
# Processing Record 50 of Set 4 | vardo
# Processing Record 1 of Set 5 | loa janan
# Processing Record 2 of Set 5 | mount gambier
# Processing Record 3 of Set 5 | duobao
# Processing Record 4 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 5 | sola
# Processing Record 6 of Set 5 | talnakh
# Processing Record 7 of Set 5 | azimur
# City not found. Skipping...
# Processing Record 8 of Set 5 | oparino
# Processing Record 9 of Set 5 | tessalit
# Processing Record 10 of Set 5 | souillac
# Processing Record 11 of Set 5 | tefe
# Processing Record 12 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 5 | yenagoa
# Processing Record 14 of Set 5 | gondanglegi
# Processing Record 15 of Set 5 | safaqis
# City not found. Skipping...
# Processing Record 16 of Set 5 | russellville
# Processing Record 17 of Set 5 | dunedin
# Processing Record 18 of Set 5 | alofi
# Processing Record 19 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 5 | bambous virieux
# Processing Record 21 of Set 5 | roald
# Processing Record 22 of Set 5 | tasiilaq
# Processing Record 23 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 5 | pevek
# Processing Record 25 of Set 5 | cambridge
# Processing Record 26 of Set 5 | tateyama
# Processing Record 27 of Set 5 | negrasi
# Processing Record 28 of Set 5 | tahta
# Processing Record 29 of Set 5 | narsaq
# Processing Record 30 of Set 5 | olafsvik
# Processing Record 31 of Set 5 | treinta y tres
# Processing Record 32 of Set 5 | raga
# Processing Record 33 of Set 5 | college
# Processing Record 34 of Set 5 | castro
# Processing Record 35 of Set 5 | hokitika
# Processing Record 36 of Set 5 | sheridan
# Processing Record 37 of Set 5 | marsh harbour
# Processing Record 38 of Set 5 | praxedis guerrero
# Processing Record 39 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 40 of Set 5 | atar
# Processing Record 41 of Set 5 | bujaru
# Processing Record 42 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 5 | pochutla
# Processing Record 44 of Set 5 | hambantota
# Processing Record 45 of Set 5 | hami
# Processing Record 46 of Set 5 | avarua
# Processing Record 47 of Set 5 | rio gallegos
# Processing Record 48 of Set 5 | kawalu
# Processing Record 49 of Set 5 | port moresby
# Processing Record 50 of Set 5 | radhanpur
# Processing Record 1 of Set 6 | saint-francois
# Processing Record 2 of Set 6 | luderitz
# Processing Record 3 of Set 6 | mutsamudu
# City not found. Skipping...
# Processing Record 4 of Set 6 | canon city
# Processing Record 5 of Set 6 | haftoni
# Processing Record 6 of Set 6 | hualmay
# Processing Record 7 of Set 6 | priargunsk
# Processing Record 8 of Set 6 | esperance
# Processing Record 9 of Set 6 | pundaguitan
# Processing Record 10 of Set 6 | komsomolskiy
# Processing Record 11 of Set 6 | anloga
# Processing Record 12 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 6 | vila velha
# Processing Record 14 of Set 6 | kokopo
# Processing Record 15 of Set 6 | severodvinsk
# Processing Record 16 of Set 6 | dianopolis
# City not found. Skipping...
# Processing Record 17 of Set 6 | leningradskiy
# Processing Record 18 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 20 of Set 6 | abu dhabi
# Processing Record 21 of Set 6 | raudeberg
# Processing Record 22 of Set 6 | ayan
# Processing Record 23 of Set 6 | xinxiang
# Processing Record 24 of Set 6 | faya
# Processing Record 25 of Set 6 | novomikhaylovskiy
# Processing Record 26 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 27 of Set 6 | basoko
# Processing Record 28 of Set 6 | port blair
# Processing Record 29 of Set 6 | aguada de pasajeros
# Processing Record 30 of Set 6 | stoyba
# City not found. Skipping...
# Processing Record 31 of Set 6 | sibolga
# Processing Record 32 of Set 6 | shuangyang
# Processing Record 33 of Set 6 | peno
# Processing Record 34 of Set 6 | kaitangata
# Processing Record 35 of Set 6 | mecca
# Processing Record 36 of Set 6 | luganville
# Processing Record 37 of Set 6 | havelock
# Processing Record 38 of Set 6 | muriwai beach
# Processing Record 39 of Set 6 | kutum
# Processing Record 40 of Set 6 | hidalgo
# Processing Record 41 of Set 6 | kamina
# Processing Record 42 of Set 6 | margate
# Processing Record 43 of Set 6 | nsanje
# Processing Record 44 of Set 6 | hobe sound
# Processing Record 45 of Set 6 | yirol
# City not found. Skipping...
# Processing Record 46 of Set 6 | shenzhen
# Processing Record 47 of Set 6 | brae
# Processing Record 48 of Set 6 | ancud
# Processing Record 49 of Set 6 | yar-sale
# Processing Record 50 of Set 6 | honningsvag
# Processing Record 1 of Set 7 | sao joao da barra
# Processing Record 2 of Set 7 | sunbury
# Processing Record 3 of Set 7 | yuli
# Processing Record 4 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 7 | westport
# Processing Record 6 of Set 7 | port-gentil
# Processing Record 7 of Set 7 | shestakovo
# Processing Record 8 of Set 7 | ambilobe
# Processing Record 9 of Set 7 | ahipara
# Processing Record 10 of Set 7 | guerrero negro
# Processing Record 11 of Set 7 | homer
# Processing Record 12 of Set 7 | kinablangan
# Processing Record 13 of Set 7 | yinchuan
# Processing Record 14 of Set 7 | touros
# Processing Record 15 of Set 7 | cabedelo
# Processing Record 16 of Set 7 | chartres
# Processing Record 17 of Set 7 | rumoi
# Processing Record 18 of Set 7 | xuanhua
# Processing Record 19 of Set 7 | kavieng
# Processing Record 20 of Set 7 | rincon
# Processing Record 21 of Set 7 | port-cartier
# Processing Record 22 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 23 of Set 7 | soyo
# Processing Record 24 of Set 7 | skerries
# Processing Record 25 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 26 of Set 7 | hofn
# Processing Record 27 of Set 7 | axim
# Processing Record 28 of Set 7 | bengkulu
# Processing Record 29 of Set 7 | tual
# Processing Record 30 of Set 7 | catamarca
# Processing Record 31 of Set 7 | marau
# Processing Record 32 of Set 7 | bilibino
# Processing Record 33 of Set 7 | nieuwpoort
# Processing Record 34 of Set 7 | terekli-mekteb
# Processing Record 35 of Set 7 | sitka
# Processing Record 36 of Set 7 | saint-georges
# Processing Record 37 of Set 7 | asyut
# Processing Record 38 of Set 7 | burica
# City not found. Skipping...
# Processing Record 39 of Set 7 | khandyga
# Processing Record 40 of Set 7 | makat
# Processing Record 41 of Set 7 | pietarsaari
# Processing Record 42 of Set 7 | sioux lookout
# Processing Record 43 of Set 7 | haines junction
# Processing Record 44 of Set 7 | uruguaiana
# Processing Record 45 of Set 7 | tuy hoa
# Processing Record 46 of Set 7 | emba
# Processing Record 47 of Set 7 | tashir
# Processing Record 48 of Set 7 | itarema
# Processing Record 49 of Set 7 | ilulissat
# Processing Record 50 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 1 of Set 8 | kokrajhar
# Processing Record 2 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 3 of Set 8 | north bend
# Processing Record 4 of Set 8 | newport
# Processing Record 5 of Set 8 | maple grove
# Processing Record 6 of Set 8 | palmer
# Processing Record 7 of Set 8 | riyadh
# Processing Record 8 of Set 8 | tilichiki
# Processing Record 9 of Set 8 | saint augustine
# Processing Record 10 of Set 8 | acari
# Processing Record 11 of Set 8 | kattivakkam
# Processing Record 12 of Set 8 | sur
# Processing Record 13 of Set 8 | vila
# Processing Record 14 of Set 8 | balabac
# Processing Record 15 of Set 8 | flinders
# Processing Record 16 of Set 8 | hamilton
# Processing Record 17 of Set 8 | erdenet
# Processing Record 18 of Set 8 | bandarbeyla
# Processing Record 19 of Set 8 | tura
# Processing Record 20 of Set 8 | afua
# Processing Record 21 of Set 8 | rawson
# Processing Record 22 of Set 8 | terrace bay
# Processing Record 23 of Set 8 | marzuq
# Processing Record 24 of Set 8 | inuvik
# Processing Record 25 of Set 8 | beloha
# Processing Record 26 of Set 8 | tyubuk
# Processing Record 27 of Set 8 | saint-augustin
# Processing Record 28 of Set 8 | zenzeli
# Processing Record 29 of Set 8 | korla
# Processing Record 30 of Set 8 | pangnirtung
# Processing Record 31 of Set 8 | acapulco
# Processing Record 32 of Set 8 | bac lieu
# Processing Record 33 of Set 8 | sao filipe
# Processing Record 34 of Set 8 | taburi
# City not found. Skipping...
# Processing Record 35 of Set 8 | okhotsk
# Processing Record 36 of Set 8 | taoudenni
# Processing Record 37 of Set 8 | duku
# Processing Record 38 of Set 8 | qingquan
# Processing Record 39 of Set 8 | fortuna
# Processing Record 40 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 8 | beringovskiy
# Processing Record 42 of Set 8 | vanavara
# Processing Record 43 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 8 | batangafo
# Processing Record 45 of Set 8 | san andres
# Processing Record 46 of Set 8 | izumo
# Processing Record 47 of Set 8 | doka
# Processing Record 48 of Set 8 | lata
# Processing Record 49 of Set 8 | carballo
# Processing Record 50 of Set 8 | sijunjung
# Processing Record 1 of Set 9 | coihaique
# Processing Record 2 of Set 9 | qaqortoq
# Processing Record 3 of Set 9 | anstruther
# Processing Record 4 of Set 9 | copiapo
# Processing Record 5 of Set 9 | lanja
# Processing Record 6 of Set 9 | oda
# Processing Record 7 of Set 9 | nyagan
# Processing Record 8 of Set 9 | moron
# Processing Record 9 of Set 9 | necochea
# Processing Record 10 of Set 9 | basco
# Processing Record 11 of Set 9 | krasnoselkup
# Processing Record 12 of Set 9 | oranjemund
# Processing Record 13 of Set 9 | bogo
# Processing Record 14 of Set 9 | maceio
# Processing Record 15 of Set 9 | adrar
# Processing Record 16 of Set 9 | waipawa
# Processing Record 17 of Set 9 | salalah
# Processing Record 18 of Set 9 | mims
# Processing Record 19 of Set 9 | yerofey pavlovich
# Processing Record 20 of Set 9 | deputatskiy
# Processing Record 21 of Set 9 | ouahigouya
# Processing Record 22 of Set 9 | merauke
# Processing Record 23 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 9 | manado
# Processing Record 26 of Set 9 | dalvik
# Processing Record 27 of Set 9 | ayr
# Processing Record 28 of Set 9 | biak
# Processing Record 29 of Set 9 | novobirilyussy
# Processing Record 30 of Set 9 | igrim
# Processing Record 31 of Set 9 | belmonte
# Processing Record 32 of Set 9 | san vicente de canete
# Processing Record 33 of Set 9 | quelimane
# Processing Record 34 of Set 9 | kloulklubed
# Processing Record 35 of Set 9 | piranshahr
# Processing Record 36 of Set 9 | pechea
# Processing Record 37 of Set 9 | lumphat
# Processing Record 38 of Set 9 | gladstone
# Processing Record 39 of Set 9 | aguadilla
# Processing Record 40 of Set 9 | blythe
# Processing Record 41 of Set 9 | porto santo
# Processing Record 42 of Set 9 | springdale
# Processing Record 43 of Set 9 | kruisfontein
# Processing Record 44 of Set 9 | swan hill
# Processing Record 45 of Set 9 | palu
# Processing Record 46 of Set 9 | bud
# Processing Record 47 of Set 9 | kahului
# Processing Record 48 of Set 9 | isiro
# Processing Record 49 of Set 9 | victoria
# Processing Record 50 of Set 9 | eskasem
# City not found. Skipping...
# Processing Record 1 of Set 10 | fort nelson
# Processing Record 2 of Set 10 | uyuni
# Processing Record 3 of Set 10 | gigmoto
# Processing Record 4 of Set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 5 of Set 10 | santa isabel do rio negro
# Processing Record 6 of Set 10 | portland
# Processing Record 7 of Set 10 | mount pleasant
# Processing Record 8 of Set 10 | mozarlandia
# Processing Record 9 of Set 10 | mamontovo
# Processing Record 10 of Set 10 | pavlodar
# Processing Record 11 of Set 10 | bonfim
# Processing Record 12 of Set 10 | hurricane
# Processing Record 13 of Set 10 | falam
# Processing Record 14 of Set 10 | husavik
# Processing Record 15 of Set 10 | bairiki
# Processing Record 16 of Set 10 | tsabong
# Processing Record 17 of Set 10 | tsaratanana
# Processing Record 18 of Set 10 | parakou
# Processing Record 19 of Set 10 | coquimbo
# Processing Record 20 of Set 10 | sapao
# City not found. Skipping...
# Processing Record 21 of Set 10 | severnyy
# Processing Record 22 of Set 10 | vigia del fuerte
# Processing Record 23 of Set 10 | seydi
# Processing Record 24 of Set 10 | santona
# Processing Record 25 of Set 10 | harbour breton
# Processing Record 26 of Set 10 | galesong
# Processing Record 27 of Set 10 | solnechnyy
# Processing Record 28 of Set 10 | moyale
# Processing Record 29 of Set 10 | ankazoabo
# Processing Record 30 of Set 10 | khorinsk
# Processing Record 31 of Set 10 | bonavista
# Processing Record 32 of Set 10 | gazojak
# Processing Record 33 of Set 10 | naranjal
# Processing Record 34 of Set 10 | sabha
# Processing Record 35 of Set 10 | nanortalik
# Processing Record 36 of Set 10 | padang
# Processing Record 37 of Set 10 | otradnoye
# Processing Record 38 of Set 10 | bytow
# Processing Record 39 of Set 10 | rio grande
# Processing Record 40 of Set 10 | gangotri
# City not found. Skipping...
# Processing Record 41 of Set 10 | shingu
# Processing Record 42 of Set 10 | kijang
# Processing Record 43 of Set 10 | livingston
# Processing Record 44 of Set 10 | rio branco
# Processing Record 45 of Set 10 | bozeman
# Processing Record 46 of Set 10 | malpe
# Processing Record 47 of Set 10 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 48 of Set 10 | eydhafushi
# Processing Record 49 of Set 10 | honiara
# Processing Record 50 of Set 10 | harper
# Processing Record 1 of Set 11 | kununurra
# Processing Record 2 of Set 11 | san patricio
# Processing Record 3 of Set 11 | caravelas
# Processing Record 4 of Set 11 | mattru
# Processing Record 5 of Set 11 | praia da vitoria
# Processing Record 6 of Set 11 | linjiang
# Processing Record 7 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 8 of Set 11 | dunayivtsi
# City not found. Skipping...
# Processing Record 9 of Set 11 | kirensk
# Processing Record 10 of Set 11 | kabompo
# Processing Record 11 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 12 of Set 11 | porto de moz
# Processing Record 13 of Set 11 | jiwani
# Processing Record 14 of Set 11 | arica
# Processing Record 15 of Set 11 | yeppoon
# Processing Record 16 of Set 11 | zhoucheng
# Processing Record 17 of Set 11 | vangaindrano
# Processing Record 18 of Set 11 | buqayq
# City not found. Skipping...
# Processing Record 19 of Set 11 | lompoc
# Processing Record 20 of Set 11 | ransang
# Processing Record 21 of Set 11 | collie
# Processing Record 22 of Set 11 | viedma
# Processing Record 23 of Set 11 | labuhan
# Processing Record 24 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 25 of Set 11 | buluang
# Processing Record 26 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 27 of Set 11 | cuajinicuilapa
# Processing Record 28 of Set 11 | dongsheng
# Processing Record 29 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 30 of Set 11 | banfora
# Processing Record 31 of Set 11 | jutai
# Processing Record 32 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 33 of Set 11 | oristano
# Processing Record 34 of Set 11 | yanai
# Processing Record 35 of Set 11 | half moon bay
# Processing Record 36 of Set 11 | nanakuli
# Processing Record 37 of Set 11 | aksha
# Processing Record 38 of Set 11 | tautira
# Processing Record 39 of Set 11 | joshimath
# Processing Record 40 of Set 11 | gamboula
# Processing Record 41 of Set 11 | mayumba
# Processing Record 42 of Set 11 | darnah
# Processing Record 43 of Set 11 | noumea
# Processing Record 44 of Set 11 | tuatapere
# Processing Record 45 of Set 11 | formosa do rio preto
# Processing Record 46 of Set 11 | wagar
# Processing Record 47 of Set 11 | mitsamiouli
# Processing Record 48 of Set 11 | palauig
# Processing Record 49 of Set 11 | kerchevskiy
# Processing Record 50 of Set 11 | yulara
# Processing Record 1 of Set 12 | kilmez
# City not found. Skipping...
# Processing Record 2 of Set 12 | assiniboia
# Processing Record 3 of Set 12 | pitea
# Processing Record 4 of Set 12 | bila tserkva
# Processing Record 5 of Set 12 | waingapu
# Processing Record 6 of Set 12 | banjar
# Processing Record 7 of Set 12 | les cayes
# Processing Record 8 of Set 12 | kavaratti
# Processing Record 9 of Set 12 | monte santo de minas
# Processing Record 10 of Set 12 | vila franca do campo
# Processing Record 11 of Set 12 | svetlogorsk
# Processing Record 12 of Set 12 | cairns
# Processing Record 13 of Set 12 | jizan
# Processing Record 14 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 15 of Set 12 | vallenar
# Processing Record 16 of Set 12 | obo
# Processing Record 17 of Set 12 | corinto
# Processing Record 18 of Set 12 | khanewal
# Processing Record 19 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 20 of Set 12 | jonkoping
# Processing Record 21 of Set 12 | hvide sande
# Processing Record 22 of Set 12 | daru
# Processing Record 23 of Set 12 | colares
# Processing Record 24 of Set 12 | bardiyah
# Processing Record 25 of Set 12 | egvekinot
# Processing Record 26 of Set 12 | dudinka
# Processing Record 27 of Set 12 | miles city
# Processing Record 28 of Set 12 | puerto madero
# Processing Record 29 of Set 12 | uvat
# Processing Record 30 of Set 12 | kralendijk
# Processing Record 31 of Set 12 | wyndham
# Processing Record 32 of Set 12 | vila do maio
# Processing Record 33 of Set 12 | gerash
# Processing Record 34 of Set 12 | alice springs
# Processing Record 35 of Set 12 | sisimiut
# Processing Record 36 of Set 12 | elblag
# Processing Record 37 of Set 12 | kampong thum
# Processing Record 38 of Set 12 | port hardy
# Processing Record 39 of Set 12 | pouembout
# Processing Record 40 of Set 12 | ust-nera
# Processing Record 41 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 12 | ganzhou
# Processing Record 43 of Set 12 | codrington
# Processing Record 44 of Set 12 | magdagachi
# Processing Record 45 of Set 12 | kuching
# Processing Record 46 of Set 12 | pisco
# Processing Record 47 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 48 of Set 12 | safwah
# City not found. Skipping...
# Processing Record 49 of Set 12 | rafaela
# Processing Record 50 of Set 12 | camden
# Processing Record 1 of Set 13 | lubao
# Processing Record 2 of Set 13 | ambon
# Processing Record 3 of Set 13 | southbridge
# Processing Record 4 of Set 13 | kiunga
# Processing Record 5 of Set 13 | rio tercero
# Processing Record 6 of Set 13 | mujiayingzi
# Processing Record 7 of Set 13 | buariki
# City not found. Skipping...
# Processing Record 8 of Set 13 | champerico
# Processing Record 9 of Set 13 | chengde
# Processing Record 10 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 13 | carolina
# Processing Record 12 of Set 13 | aykhal
# Processing Record 13 of Set 13 | bon air
# Processing Record 14 of Set 13 | port shepstone
# Processing Record 15 of Set 13 | balad
# Processing Record 16 of Set 13 | arona
# Processing Record 17 of Set 13 | wismar
# Processing Record 18 of Set 13 | paamiut
# Processing Record 19 of Set 13 | tiarei
# Processing Record 20 of Set 13 | bolshaya irba
# City not found. Skipping...
# Processing Record 21 of Set 13 | poltavka
# Processing Record 22 of Set 13 | otukpo
# Processing Record 23 of Set 13 | kerouane
# Processing Record 24 of Set 13 | mogadishu
# Processing Record 25 of Set 13 | kefar weradim
# Processing Record 26 of Set 13 | jaen
# Processing Record 27 of Set 13 | mugumu
# Processing Record 28 of Set 13 | nome
# Processing Record 29 of Set 13 | gorele
# Processing Record 30 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 31 of Set 13 | elhovo
# Processing Record 32 of Set 13 | ouesso
# Processing Record 33 of Set 13 | north platte
# Processing Record 34 of Set 13 | bambanglipuro
# Processing Record 35 of Set 13 | yagodnoye
# Processing Record 36 of Set 13 | yunjinghong
# City not found. Skipping...
# Processing Record 37 of Set 13 | christchurch
# Processing Record 38 of Set 13 | camopi
# Processing Record 39 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 13 | indramayu
# Processing Record 41 of Set 13 | makaha
# Processing Record 42 of Set 13 | san-pedro
# Processing Record 43 of Set 13 | boende
# Processing Record 44 of Set 13 | bonthe
# Processing Record 45 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 46 of Set 13 | springfield
# Processing Record 47 of Set 13 | norrtalje
# Processing Record 48 of Set 13 | conde
# Processing Record 49 of Set 13 | kirksville
# Processing Record 50 of Set 13 | pelym
# Processing Record 1 of Set 14 | altayskoye
# Processing Record 2 of Set 14 | okoneshnikovo
# Processing Record 3 of Set 14 | ondjiva
# Processing Record 4 of Set 14 | virginia beach
# Processing Record 5 of Set 14 | kologriv
# Processing Record 6 of Set 14 | turayf
# Processing Record 7 of Set 14 | alexandria
# Processing Record 8 of Set 14 | emborion
# Processing Record 9 of Set 14 | sao cristovao
# Processing Record 10 of Set 14 | peniche
# Processing Record 11 of Set 14 | lorengau
# Processing Record 12 of Set 14 | mushie
# Processing Record 13 of Set 14 | vestmanna
# Processing Record 14 of Set 14 | betafo
# Processing Record 15 of Set 14 | richards bay
# Processing Record 16 of Set 14 | nanao
# Processing Record 17 of Set 14 | olbia
# Processing Record 18 of Set 14 | road town
# Processing Record 19 of Set 14 | mago
# Processing Record 20 of Set 14 | orgun
# City not found. Skipping...
# Processing Record 21 of Set 14 | nuuk
# Processing Record 22 of Set 14 | bosaso
# Processing Record 23 of Set 14 | zyryanka
# Processing Record 24 of Set 14 | astaneh-ye ashrafiyeh
# Processing Record 25 of Set 14 | freeport
# Processing Record 26 of Set 14 | denpasar
# Processing Record 27 of Set 14 | kanalion
# Processing Record 28 of Set 14 | ipameri
# Processing Record 29 of Set 14 | mamallapuram
# Processing Record 30 of Set 14 | ajdabiya
# Processing Record 31 of Set 14 | san javier
# Processing Record 32 of Set 14 | presidente olegario
# Processing Record 33 of Set 14 | kampot
# Processing Record 34 of Set 14 | hervey bay
# Processing Record 35 of Set 14 | tiruvottiyur
# City not found. Skipping...
# Processing Record 36 of Set 14 | clonmel
# Processing Record 37 of Set 14 | vernon
# Processing Record 38 of Set 14 | santa marinella
# Processing Record 39 of Set 14 | acarau
# Processing Record 40 of Set 14 | jimo
# Processing Record 41 of Set 14 | nishihara
# Processing Record 42 of Set 14 | shitanjing
# Processing Record 43 of Set 14 | sibirtsevo
# City not found. Skipping...
# Processing Record 44 of Set 14 | morant bay
# Processing Record 45 of Set 14 | garowe
# Processing Record 46 of Set 14 | cockburn town
# Processing Record 47 of Set 14 | uruzgan
# Processing Record 48 of Set 14 | seoul
# Processing Record 49 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 50 of Set 14 | itambe
# Processing Record 1 of Set 15 | esso
# Processing Record 2 of Set 15 | auki
# Processing Record 3 of Set 15 | diapaga
# Processing Record 4 of Set 15 | mokolo
# Processing Record 5 of Set 15 | haademeeste
# City not found. Skipping...
# Processing Record 6 of Set 15 | stephenville
# Processing Record 7 of Set 15 | puerto penasco
# Processing Record 8 of Set 15 | vikindu
# Processing Record 9 of Set 15 | turtkul
# City not found. Skipping...
# Processing Record 10 of Set 15 | aracati
# Processing Record 11 of Set 15 | masyaf
# Processing Record 12 of Set 15 | pakxan
# Processing Record 13 of Set 15 | hay river
# Processing Record 14 of Set 15 | fayaoue
# Processing Record 15 of Set 15 | san lorenzo
# Processing Record 16 of Set 15 | leh
# Processing Record 17 of Set 15 | oeiras
# Processing Record 18 of Set 15 | angoche
# Processing Record 19 of Set 15 | bubaque
# Processing Record 20 of Set 15 | huazolotitlan
# City not found. Skipping...
# Processing Record 21 of Set 15 | launceston
# Processing Record 22 of Set 15 | sorkjosen
# Processing Record 23 of Set 15 | sumbawa
# City not found. Skipping...
# Processing Record 24 of Set 15 | buin
# Processing Record 25 of Set 15 | kempsey
# Processing Record 26 of Set 15 | male
# Processing Record 27 of Set 15 | port hedland
# Processing Record 28 of Set 15 | flagstaff
# Processing Record 29 of Set 15 | tecpan
# Processing Record 30 of Set 15 | myitkyina
# Processing Record 31 of Set 15 | altus
# Processing Record 32 of Set 15 | madang
# Processing Record 33 of Set 15 | los llanos de aridane
# Processing Record 34 of Set 15 | guarapari
# Processing Record 35 of Set 15 | huinan
# Processing Record 36 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 37 of Set 15 | maibong
# Processing Record 38 of Set 15 | chichicapam
# City not found. Skipping...
# Processing Record 39 of Set 15 | hobyo
# Processing Record 40 of Set 15 | breyten
# Processing Record 41 of Set 15 | dickinson
# Processing Record 42 of Set 15 | gamba
# Processing Record 43 of Set 15 | acajutla
# Processing Record 44 of Set 15 | boyolangu
# Processing Record 45 of Set 15 | mehamn
# Processing Record 46 of Set 15 | nieuw amsterdam
# Processing Record 47 of Set 15 | jalu
# Processing Record 48 of Set 15 | lakselv
# Processing Record 49 of Set 15 | funtua
# Processing Record 50 of Set 15 | sao geraldo do araguaia
# Processing Record 1 of Set 16 | miranda de ebro
# Processing Record 2 of Set 16 | umm lajj
# Processing Record 3 of Set 16 | griffith
# Processing Record 4 of Set 16 | comodoro rivadavia
# Processing Record 5 of Set 16 | sambava
# Processing Record 6 of Set 16 | banda aceh
# Processing Record 7 of Set 16 | goundam
# Processing Record 8 of Set 16 | eidsvag
# Processing Record 9 of Set 16 | geraldton
# Processing Record 10 of Set 16 | havre
# Processing Record 11 of Set 16 | usakos
# Processing Record 12 of Set 16 | olivet
# Processing Record 13 of Set 16 | mahon
# Processing Record 14 of Set 16 | goderich
# Processing Record 15 of Set 16 | vilhena
# Processing Record 16 of Set 16 | maromitsa
# Processing Record 17 of Set 16 | dordrecht
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# 689

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.to_csv("Weather_Database/WeatherPy_Database.csv", index_label="City_ID")

# %%
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Punta Arenas      CL -53.1500  -70.9167     41.11        65          20
# 1      Hermanus      ZA -34.4187   19.2345     60.53        86          37
# 2         Kapaa      US  22.0752 -159.3190     77.11        85          56
# 3        Dwarka      IN  22.2394   68.9678     82.92        83          48
# 4         Minas      UY -34.3759  -55.2377     64.15        53          37
# 5         Tiksi      RU  71.6872  128.8694     30.51        88         100
# 6      Cherskiy      RU  68.7500  161.3000     48.31        57          80
# 7       Tondano      ID   1.3038  124.9112     68.09        88          81
# 8  Ponta Do Sol      PT  32.6667  -17.1000     73.00        76          20
# 9        Dingle      PH  10.9995  122.6711     77.43        89          97
#
#    Wind Speed Weather description
# 0       17.27          few clouds
# 1        8.28    scattered clouds
# 2        1.99       broken clouds
# 3       23.20    scattered clouds
# 4        5.44    scattered clouds
# 5        5.93     overcast clouds
# 6        9.66       broken clouds
# 7        2.17       broken clouds
# 8        1.28          few clouds
# 9        4.27     overcast clouds
